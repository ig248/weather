# %%
import os.path
import pygrib

# %%
data_dir = 'data'
file = 'gep01.t06z.pgrb2f00'
grib_file = os.path.join(data_dir, file)

# %%
grbs = pygrib.open(grib_file)

# %%
cloud = grbs.select(name='Total Cloud Cover')
len(cloud)
# Out:
# 1

# %%
c = cloud[0]

# %%
plt.figure(figsize=(10, 4))
plt.imshow(c.values, cmap='gray', extent=(0, 360, -90, 90))
plt.colorbar()
plt.title('Cloud cover %')
plt.savefig('cloud.png')

# %%
temp = grbs.select(name='Temperature', typeOfLevel='surface', units='K')
len(temp)
# Out:
# 1

# %%
K0 = 273.15

# %%
t.values.shape
# Out:
# (181, 360)

# %%
import matplotlib.pyplot as plt

# %%
lat, lon = t.latlons()

# %%
lat.shape, lon.shape
# Out:
# ((181, 360), (181, 360))

# %%
T = t.values - K0

# %%
T.min(), T.max(), T.mean()
# Out:
# (-64.45, 60.150024, 6.9296865)

# %%
plt.figure(figsize=(10, 4))
plt.imshow(T, cmap='inferno', extent=(0, 360, -90, 90))
plt.colorbar()
plt.title('Surface temperature, C')
plt.savefig('temp.png')
